# %%
import heapq

heuristic = {}
for node in graph:
    heuristic[node] = int(input(f"Enter heuristic value for {node}: "))

goal = input("Enter goal node: ")

def best_first_search(graph, start, goal, heuristic):
    visited = set()
    heap = []
    heapq.heappush(heap, (heuristic[start], start))

    print("Best-First Search Traversal:")
    while heap:
        _, node = heapq.heappop(heap)
        if node == goal:
            print(f"\nReached goal: {node}")
            return
        if node not in visited:
            print(node, end=' ')
            visited.add(node)
            for neighbor in graph[node]:
                if neighbor not in visited:
                    heapq.heappush(heap, (heuristic[neighbor], neighbor))

best_first_search(graph, start, goal, heuristic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2720794434.py in <cell line: 0>()
#       2
#       3 heuristic = {}
# ----> 4 for node in graph:
#       5     heuristic[node] = int(input(f"Enter heuristic value for {node}: "))
#       6
#
# NameError: name 'graph' is not defined
