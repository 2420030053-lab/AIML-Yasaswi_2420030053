# %%
from sklearn.cluster import KMeans
import numpy as np

n = int(input("Enter number of points: "))
X = []

for i in range(n):
    xi = float(input(f"Enter feature X[{i}]: "))
    yi = float(input(f"Enter feature Y[{i}]: "))
    X.append([xi, yi])

k = int(input("Enter number of clusters K: "))
model = KMeans(n_clusters=k, random_state=0)
model.fit(X)

print("Cluster centers:", model.cluster_centers_)
print("Labels:", model.labels_)
# Out:
# Enter number of points: 6
# Enter feature X[0]: ]8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1072903648.py in <cell line: 0>()
#       6
#       7 for i in range(n):
# ----> 8     xi = float(input(f"Enter feature X[{i}]: "))
#       9     yi = float(input(f"Enter feature Y[{i}]: "))
#      10     X.append([xi, yi])
#
# ValueError: could not convert string to float: ']8'
